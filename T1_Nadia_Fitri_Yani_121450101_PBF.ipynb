# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiafitri28/PBF/blob/main/T1_Nadia_Fitri_Yani_121450101_PBF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan object oriented (minimal 3)!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan
# paradigma object oriented dibandingkan dengan functional (minimal 3) !

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan
# paradigma procedural dibandingkan dengan functional (minimal 3) !

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Apa yang dimaksud dengan pure functional programming language?

# %% [markdown]
# paradigma pemrograman yang berkutat pada komputasi yang terjadi di dalam fungsi matematis dan menghindari terjadinya perubahan data. Yang dimaksud dengan fungsi matematis sendiri adalah sebuah hubungan antara input yang akan mengembalikan output

# %% [markdown]
#  5. Dari bahasa pemrograman FP di slide sebelumnya ( slide 14 ) , manakah
# yang termasuk pure functional programming language?

# %% [markdown]
# Lisp, Haskell, dan Standard ML
